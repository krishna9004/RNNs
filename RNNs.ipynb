# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# %%
# Generate sequences of random integers
def generate_sequences(num_sequences, max_length, vocab_size):
    sequences = []
    labels = []
    for _ in range(num_sequences):
        length = np.random.randint(1, max_length + 1)
        seq = np.random.randint(0, vocab_size, length)
        label = np.sum(seq) % 2  # 0 if sum is even, 1 if odd
        sequences.append(seq)
        labels.append(label)
    return sequences, labels

# Parameters
num_sequences = 1000
max_length = 10
vocab_size = 10

# Generate data
sequences, labels = generate_sequences(num_sequences, max_length, vocab_size)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Pad sequences to the same length
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# Convert labels to numpy array
labels = np.array(labels)

# %%
# Define the model
model = Sequential()
model.add(SimpleRNN(32, input_shape=(max_length, 1)))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Reshape input data
X = padded_sequences.reshape((num_sequences, max_length, 1))
y = labels

# Train the model
model.fit(X, y, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5104 - loss: 0.7028 - val_accuracy: 0.5400 - val_loss: 0.6909
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5648 - loss: 0.6845 - val_accuracy: 0.4900 - val_loss: 0.6974
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5619 - loss: 0.6898 - val_accuracy: 0.4850 - val_loss: 0.7038
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5806 - loss: 0.6897 - val_accuracy: 0.4800 - val_loss: 0.6999
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5722 - loss: 0.6859 - val_accuracy: 0.4950 - val_loss: 0.7016
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6006 - loss: 0.6791 - val_accuracy: 0.4800 - val_loss: 0.7020
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5668 - loss: 0.6837 - val_accuracy: 0.4850 - val_loss: 0.7035
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5923 - loss: 0.6777 - val_accuracy: 0.4800 - val_loss: 0.7008
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5846 - loss: 0.6764 - val_accuracy: 0.4800 - val_loss: 0.7019
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5841 - loss: 0.6777 - val_accuracy: 0.4850 - val_loss: 0.6984

# %%
# Evaluate on the training data
loss, accuracy = model.evaluate(X, y)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5788 - loss: 0.6797
# Accuracy: 56.30%

# %%
# Predict on new data
test_seq = np.array([[1, 3, 5]])
test_seq_padded = pad_sequences(test_seq, maxlen=max_length, padding='post')
test_seq_reshaped = test_seq_padded.reshape((1, max_length, 1))

prediction = model.predict(test_seq_reshaped)
predicted_label = int(prediction.round()[0][0])
print(f"Predicted Label: {'Even' if predicted_label == 0 else 'Odd'}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Predicted Label: Even
